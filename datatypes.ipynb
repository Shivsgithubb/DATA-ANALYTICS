# %%
poem = '''johnny johnny yes papa
eating sugar? np papa'''
print(poem)
# Out:
# johnny johnny yes papa
# eating sugar? np papa

# %%
fruits = ('apple','mango','guava','guava','orange')
print(fruits)
# Out:
# ('apple', 'mango', 'guava', 'guava', 'orange')

# %%
fruits = ['apple','mango','guava','guava','orange']
print(fruits)
# Out:
# ['apple', 'mango', 'guava', 'guava', 'orange']

# %%
fruits = {'apple','mango','guava','guava','orange'}
print(fruits)
# Out:
# {'apple', 'guava', 'mango', 'orange'}

# %%
student = {
    'name' : 'john',
    'age' : 22,
    "course" : 'BCA',
    'college' : 'XYZ'
}
print (student)
# Out:
# {'name': 'john', 'age': 22, 'course': 'BCA', 'college': 'XYZ'}

# %%
# to check datatype
type(student)
# Out:
# dict

# %%
# type casting

a = input('enter a number: ')
b = int (a)
print(b)
# Out:
# 65

# %%
type(b)
# Out:
# int

# %%
a = int(input('enter a number: '))
print(a)
# Out:
# 65
