# %%
name ='shivendra'
for i in name:
    print(name[:3])
# Out:
# shi
# shi
# shi
# shi
# shi
# shi
# shi
# shi
# shi

# %%
#string concatenation
Fname = 'shivendra'
Lname = 'verma'
print(Fname +' '+Lname)
# Out:
# shivendra verma

# %%
#string duplication
x = 'HI'
print(x * 3)
# Out:
# HIHIHI

# %%
#to convert in capital letter
x = 'beautiful'
x.upper()
# Out:
# 'BEAUTIFUL'

# %%
#to convert in small letter
x.lower()
# Out:
# 'beautiful'

# %%
x.capitalize()
# Out:
# 'Beautiful'

# %%
y = 'welcome to my world'
y.title()
# Out:
# 'Welcome To My World'

# %%
y.split()
# Out:
# ['welcome', 'to', 'my', 'world']

# %%
poem = '''johnny johnny yes papa
eating sugar no papa
johnny johnny yes papa
eating sugar no papa'''
print(poem)
# Out:
# johnny johnny yes papa
# eating sugar no papa
# johnny johnny yes papa
# eating sugar no papa

# %%
poem.splitlines()
# Out:
# ['johnny johnny yes papa',
#  'eating sugar no papa',
#  'johnny johnny yes papa',
#  'eating sugar no papa']

# %%
poem.find('papa')
# Out:
# 18

# %%
p = poem.replace('papa','mama').replace('sugar','poison').replace('lies','yes')
print(p)
# Out:
# johnny johnny yes mama
# eating poison no mama
# johnny johnny yes mama
# eating poison no mama
