# %%
a = 5
b = 7
print(a+b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# 12
# 35
# 0.7142857142857143
# 5
# 0
# 78125

# %%
a = 5
b = 7
print(a+b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# 12
# 35
# 0.7142857142857143
# 5
# 0
# 78125

# %% [markdown]
# - h
#   - j
#   - o
# - ni
#   - j
#   - l

# %% [markdown]
# <loremipsum34>
#
#   this is another paragrap
#   cuievh

# %% [markdown]
# - hi
#   - huyiuj
